# %%
# Import our tools
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
# Load the dataset
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)
# First look: shape and types
print(f"Dataset shape: {df.shape}")
print("\nFirst 5 rows:")
df.head()
# Out:
# Dataset shape: (150, 5)
#
# First 5 rows:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# What does the data look like numerically?
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# Plot petal length by species
fig, ax = plt.subplots(figsize=(8, 5))
for species, group in df.groupby('species'): ax.scatter(group['petal length (cm)'], group['petal width (cm)'], label=species, alpha=0.7)
ax.set_xlabel('Petal Length (cm)')
ax.set_ylabel('Petal Width (cm)')
ax.set_title('Iris: Petal Dimensions by Species')
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1911/3886887709.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for species, group in df.groupby('species'): ax.scatter(group['petal length (cm)'], group['petal width (cm)'], label=species, alpha=0.7)

# %%
# Try these yourself:
# 1. Which species has the longest sepals on average?
df.groupby('species')['sepal length (cm)'].mean()
# Out:
# /tmp/ipykernel_1911/1783058887.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('species')['sepal length (cm)'].mean()
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal length (cm), dtype: float64

# %%
# 2. Are there any missing values?
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64
